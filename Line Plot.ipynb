# %% [markdown]
# ## **Create a Line plot**
#
# This tutorial is for a line plot

# %%
a = [1,2,3,4,5,6]
b = [-1,-2,-3,-4,-5,-6]

import matplotlib.pyplot as plt

plt.plot(a,b)
plt.show()

# %%
plt.plot(b,a)
plt.show()
